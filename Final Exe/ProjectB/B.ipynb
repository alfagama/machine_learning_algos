# %%
# !pip install pandas

# %%
# !pip install sklearn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
dataset = pd.read_csv("Data/fuel_emissions.csv",
                      sep=',',
                      header=0,  # no header, alternative header = header_col
                      index_col=None  # no index, alternative header = index_row
                      )
# Out:
# c:\users\giorgos\.virtualenvs\machine_learning_msc_exe_repo-tqmaiiy4\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33088 entries, 0 to 33087
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   file                    33088 non-null  object
#  1   year                    33088 non-null  int64
#  2   manufacturer            33088 non-null  object
#  3   model                   33088 non-null  object
#  4   description             33088 non-null  object
#  5   euro_standard           33088 non-null  int64
#  6   tax_band                7837 non-null   object
#  7   transmission            33078 non-null  object
#  8   transmission_type       32747 non-null  object
#  9   engine_capacity         33081 non-null  float64
#  10  fuel_type               33088 non-null  object
#  11  urban_metric            33075 non-null  float64
#  12  extra_urban_metric      33075 non-null  float64
#  13  combined_metric         33081 non-null  float64
# ...

# %%
dataset.describe()
# Out:
#                year  euro_standard  engine_capacity  urban_metric  \
# count  33088.000000   33088.000000     33081.000000  33075.000000
# mean    2009.181879       4.311775      2182.510807      9.922113
# std        2.587528       0.635053       915.477253      3.841249
# min     2005.000000       3.000000       209.000000      3.100000
# 25%     2007.000000       4.000000      1598.000000      7.300000
# 50%     2009.000000       4.000000      1984.000000      9.100000
# 75%     2011.000000       5.000000      2393.000000     11.500000
# max     2013.000000       6.000000      8285.000000     36.300000
#
#        extra_urban_metric  combined_metric  urban_imperial  \
# count        33075.000000     33081.000000    33075.000000
# mean             5.904508         7.374487       32.221956
# std              1.606424         2.411476       10.983544
# min              2.900000         1.200000        7.800000
# 25%              4.800000         5.700000       24.600000
# ...

# %%
dataset['transmission'].value_counts()
# Out:
# M6            9720
# M5            7535
# A6            3221
# A5            2582
# A7            1693
# A4            1322
# D6             731
# CVT            666
# QM6            624
# A8             606
# 5MT            555
# 6MT            545
# D7             449
# QA6            372
# AV             368
# 6AT            203
# 5AT            156
# QD7            132
# AMT6            92
# MTA             87
# E-CVT           86
# 5MTx2           82
# 4AT             81
# MTA5            79
# QD6             75
# S/A6            75
# SAT5            73
# 5 AMT           70
# ASM             53
# SAT6            46
# QA8             45
# Multi5          43
# M6/S6           43
# SM6             38
# M7              32
# M5x2            28
# 4ATx2           27
# M6x2            26
# MT              26
# DCT7            25
# M6-AWD          24
# A6x2            24
# i-SHIFT         23
# SMG 7           23
# A5x2            21
# DM6             20
# A6-AWD          19
# ...

# %%
len(dataset)
# Out:
# 33088

# %%
dataset.head(5)
# Out:
#                          file  year manufacturer         model  \
# 0  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 1  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 2  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 3  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 4  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
#
#                   description  euro_standard tax_band transmission  \
# 0                        116i              4      NaN           M5
# 1      118d - from March 2005              4      NaN           M6
# 2  118d - up to February 2005              4      NaN           M6
# 3                        118i              4      NaN           M5
# 4                        118i              4      NaN           A6
#
#   transmission_type  engine_capacity fuel_type  urban_metric  \
# 0            Manual           1596.0    Petrol          10.5
# ...

# %%
dataset = dataset[[col for col in dataset.columns if col != 'fuel_cost_12000_miles'] + ['fuel_cost_12000_miles']]
dataset.head(5)
# Out:
#                          file  year manufacturer         model  \
# 0  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 1  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 2  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 3  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 4  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
#
#                   description  euro_standard tax_band transmission  \
# 0                        116i              4      NaN           M5
# 1      118d - from March 2005              4      NaN           M6
# 2  118d - up to February 2005              4      NaN           M6
# 3                        118i              4      NaN           M5
# 4                        118i              4      NaN           A6
#
#   transmission_type  engine_capacity fuel_type  urban_metric  \
# 0            Manual           1596.0    Petrol          10.5
# ...

# %%
nulls = dataset.isnull().sum()
nulls
# Out:
# file                          0
# year                          0
# manufacturer                  0
# model                         0
# description                   0
# euro_standard                 0
# tax_band                  25251
# transmission                 10
# transmission_type           341
# engine_capacity               7
# fuel_type                     0
# urban_metric                 13
# extra_urban_metric           13
# combined_metric               7
# urban_imperial               13
# extra_urban_imperial         13
# combined_imperial             7
# noise_level                   0
# co2                           0
# thc_emissions             16599
# co_emissions                 24
# nox_emissions                70
# thc_nox_emissions         27658
# particulates_emissions    19912
# standard_12_months        29571
# standard_6_months         30162
# first_year_12_months      29571
# first_year_6_months       31669
# fuel_cost_12000_miles        10
# ...

# %%
dataset = dataset.dropna(thresh=len(dataset) - (round((len(dataset) / 3), 0)), axis=1)
dataset.describe()
# Out:
#                year  euro_standard  engine_capacity  urban_metric  \
# count  33088.000000   33088.000000     33081.000000  33075.000000
# mean    2009.181879       4.311775      2182.510807      9.922113
# std        2.587528       0.635053       915.477253      3.841249
# min     2005.000000       3.000000       209.000000      3.100000
# 25%     2007.000000       4.000000      1598.000000      7.300000
# 50%     2009.000000       4.000000      1984.000000      9.100000
# 75%     2011.000000       5.000000      2393.000000     11.500000
# max     2013.000000       6.000000      8285.000000     36.300000
#
#        extra_urban_metric  combined_metric  urban_imperial  \
# count        33075.000000     33081.000000    33075.000000
# mean             5.904508         7.374487       32.221956
# std              1.606424         2.411476       10.983544
# min              2.900000         1.200000        7.800000
# 25%              4.800000         5.700000       24.600000
# ...

# %%
new_nulls = dataset.isnull().sum()
new_nulls
# Out:
# file                       0
# year                       0
# manufacturer               0
# model                      0
# description                0
# euro_standard              0
# transmission              10
# transmission_type        341
# engine_capacity            7
# fuel_type                  0
# urban_metric              13
# extra_urban_metric        13
# combined_metric            7
# urban_imperial            13
# extra_urban_imperial      13
# combined_imperial          7
# noise_level                0
# co2                        0
# co_emissions              24
# nox_emissions             70
# fuel_cost_12000_miles     10
# dtype: int64

# %%
dataset.head(5)
# Out:
#                          file  year manufacturer         model  \
# 0  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 1  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 2  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 3  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
# 4  Part_A_Euro_IV_may2005.csv  2005          BMW  1 Series E87
#
#                   description  euro_standard transmission transmission_type  \
# 0                        116i              4           M5            Manual
# 1      118d - from March 2005              4           M6            Manual
# 2  118d - up to February 2005              4           M6            Manual
# 3                        118i              4           M5            Manual
# 4                        118i              4           A6         Automatic
#
#    engine_capacity fuel_type  urban_metric  extra_urban_metric  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33088 entries, 0 to 33087
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   file                   33088 non-null  object
#  1   year                   33088 non-null  int64
#  2   manufacturer           33088 non-null  object
#  3   model                  33088 non-null  object
#  4   description            33088 non-null  object
#  5   euro_standard          33088 non-null  int64
#  6   transmission           33078 non-null  object
#  7   transmission_type      32747 non-null  object
#  8   engine_capacity        33081 non-null  float64
#  9   fuel_type              33088 non-null  object
#  10  urban_metric           33075 non-null  float64
#  11  extra_urban_metric     33075 non-null  float64
#  12  combined_metric        33081 non-null  float64
#  13  urban_imperial         33075 non-null  float64
# ...

# %%
drop_columns = ["file", "manufacturer", "model", "description"]
dataset = dataset.drop(drop_columns, axis=1)
dataset.head(5)
# Out:
#    year  euro_standard transmission transmission_type  engine_capacity  \
# 0  2005              4           M5            Manual           1596.0
# 1  2005              4           M6            Manual           1995.0
# 2  2005              4           M6            Manual           1995.0
# 3  2005              4           M5            Manual           1995.0
# 4  2005              4           A6         Automatic           1995.0
#
#   fuel_type  urban_metric  extra_urban_metric  combined_metric  \
# 0    Petrol          10.5                 5.9              7.5
# 1    Diesel           7.7                 4.5              5.6
# 2    Diesel           7.7                 4.5              5.6
# 3    Petrol          10.1                 5.7              7.3
# 4    Petrol          10.7                 6.1              7.8
#
#    urban_imperial  extra_urban_imperial  combined_imperial  noise_level  co2  \
# 0            26.9                  47.9               37.7         73.0  181
# ...

# %%
dataset['transmission_type'].value_counts()
# Out:
# Manual       19282
# Automatic    13465
# Name: transmission_type, dtype: int64

# %%
# dataset = pd.get_dummies(dataset, columns=['transmission_type']).head()
# dataset

# %%
dataset.isnull().sum()
# Out:
# year                       0
# euro_standard              0
# transmission              10
# transmission_type        341
# engine_capacity            7
# fuel_type                  0
# urban_metric              13
# extra_urban_metric        13
# combined_metric            7
# urban_imperial            13
# extra_urban_imperial      13
# combined_imperial          7
# noise_level                0
# co2                        0
# co_emissions              24
# nox_emissions             70
# fuel_cost_12000_miles     10
# dtype: int64

# %%
dataset.describe()
# Out:
#                year  euro_standard  engine_capacity  urban_metric  \
# count  33088.000000   33088.000000     33081.000000  33075.000000
# mean    2009.181879       4.311775      2182.510807      9.922113
# std        2.587528       0.635053       915.477253      3.841249
# min     2005.000000       3.000000       209.000000      3.100000
# 25%     2007.000000       4.000000      1598.000000      7.300000
# 50%     2009.000000       4.000000      1984.000000      9.100000
# 75%     2011.000000       5.000000      2393.000000     11.500000
# max     2013.000000       6.000000      8285.000000     36.300000
#
#        extra_urban_metric  combined_metric  urban_imperial  \
# count        33075.000000     33081.000000    33075.000000
# mean             5.904508         7.374487       32.221956
# std              1.606424         2.411476       10.983544
# min              2.900000         1.200000        7.800000
# 25%              4.800000         5.700000       24.600000
# ...

# %%
# dataset = dataset[pd.notnull(dataset["fuel_cost_12000_miles"])]
dataset["fuel_cost_12000_miles"] = dataset["fuel_cost_12000_miles"].fillna[0]
# titanic["Embarked"] = titanic["Embarked"].fillna(list(dict(embarked))[0])
dataset.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-2d0855688eeb> in <module>
#       1 # dataset = dataset[pd.notnull(dataset["fuel_cost_12000_miles"])]
# ----> 2 dataset["fuel_cost_12000_miles"] = dataset["fuel_cost_12000_miles"].fillna[0]
#       3 # titanic["Embarked"] = titanic["Embarked"].fillna(list(dict(embarked))[0])
#       4 dataset.info()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
dataset['fuel_type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d5ca88415c60> in <module>
# ----> 1 dataset['fuel_type'].value_counts()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
dataset.fillna(df.mean())
dataset.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-973e40df9470> in <module>
# ----> 1 dataset.fillna(df.mean())
#       2 dataset.isnull().sum()
#
# AttributeError: 'NoneType' object has no attribute 'fillna'

# %%
dataset_ints_and_floats = dataset.select_dtypes(include=['float64', 'int64']).copy()
dataset_ints_and_floats.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ca910609d9b0> in <module>
# ----> 1 dataset_ints_and_floats = dataset.select_dtypes(include=['float64', 'int64']).copy()
#       2 dataset_ints_and_floats.head(5)
#
# AttributeError: 'NoneType' object has no attribute 'select_dtypes'

# %%
dataset_objects = dataset.select_dtypes(include=['object']).copy()
dataset_objects.head(5)

# %%
dataset_objects['transmission'].value_counts()

# %%
# replace_dic = {"num_doors":     {"four": 4, "two": 2},
#                "num_cylinders": {"four": 4, "six": 6, "five": 5, "eight": 8,
#                                   "two": 2, "twelve": 12, "three":3 }}
# obj_df = obj_df.replace(cleanup_nums)
# obj_df.head()

# %%
dataset_objects_new = dataset_objects
dataset_objects_new['transmission'] = dataset_objects_new['transmission'].astype('category')
dataset_objects_new = dataset_objects_new.drop('new_col', axis=1)
dataset_objects_new.dtypes

# %%
dataset_objects_new['new'] = dataset_objects_new['transmission'].cat.codes
dataset_objects_new.head(5)

# %%
dataset_objects_new.dtypes

# %%
pd.get_dummies(dataset_objects_new, columns=['transmission_type']).head()

# %%
pd.get_dummies(dataset_objects_new, columns=['transmission']).head()

# %%
dataset_objects['fuel_type'].value_counts()

# %%
pd.get_dummies(dataset_objects, columns=["fuel_type"], prefix=["fuel"]).head()

# %%
import numpy as np

# %%
dataset_objects["transmission_M6"] = np.where(dataset_objects["transmission"].str.contains("M6"), 1, 0)
dataset_objects["transmission_M5"] = np.where(dataset_objects["transmission"].str.contains("M5"), 1, 0)
dataset_objects["transmission_A6"] = np.where(dataset_objects["transmission"].str.contains("A6"), 1, 0)
dataset_objects["transmission_A5"] = np.where(dataset_objects["transmission"].str.contains("A5"), 1, 0)
dataset_objects["transmission_A7"] = np.where(dataset_objects["transmission"].str.contains("A7"), 1, 0)
dataset_objects["transmission_A4"] = np.where(dataset_objects["transmission"].str.contains("A4"), 1, 0)
dataset_objects["transmission_D6"] = np.where(dataset_objects["transmission"].str.contains("D6"), 1, 0)
dataset_objects["transmission_CVT"] = np.where(dataset_objects["transmission"].str.contains("CVT"), 1, 0)
dataset_objects["transmission_QM6"] = np.where(dataset_objects["transmission"].str.contains("QM6"), 1, 0)
dataset_objects["transmission_A8"] = np.where(dataset_objects["transmission"].str.contains("A8"), 1, 0)
dataset_objects["transmission_5MT"] = np.where(dataset_objects["transmission"].str.contains("5MT"), 1, 0)
dataset_objects["transmission_6MT"] = np.where(dataset_objects["transmission"].str.contains("6MT"), 1, 0)
dataset_objects["transmission_D7"] = np.where(dataset_objects["transmission"].str.contains("D7"), 1, 0)
dataset_objects["transmission_QA6"] = np.where(dataset_objects["transmission"].str.contains("QA6"), 1, 0)
dataset_objects["transmission_AV"] = np.where(dataset_objects["transmission"].str.contains("AV"), 1, 0)
dataset_objects["transmission_6AT"] = np.where(dataset_objects["transmission"].str.contains("6AT"), 1, 0)
dataset_objects["transmission_5AT"] = np.where(dataset_objects["transmission"].str.contains("5AT"), 1, 0)
dataset_objects["transmission_QD7"] = np.where(dataset_objects["transmission"].str.contains("QD7"), 1, 0)
dataset_objects

# %%
dataset_objects.head(5)
